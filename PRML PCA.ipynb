# %% [markdown]
# ### (1) i. Write a piece of code to run the PCA algorithm on this data-set. How much of the variance in the data-set is explained by each of the principal components?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
df=pd.read_csv('Dataset.csv',header=None)
df.columns=['x','y']
shape=df.shape
n=shape[0]
d=shape[1]
df
# Out:
#            x        y
# 0    0.14300  0.98493
# 1   -0.30467  0.98562
# 2    0.46625 -0.84003
# 3    0.94847  0.37222
# 4   -0.96871 -0.26697
# ..       ...      ...
# 995  4.48210 -7.40030
# 996 -3.49630  8.63860
# 997  6.10620 -5.98640
# 998 -7.40940 -5.52050
# 999 -0.12948 -8.80360
#
# [1000 rows x 2 columns]

# %%
df.plot(x ='x', y='y', kind = 'scatter')
plt.xlabel('feature1')
plt.ylabel('feature2')
plt.title('Data Points')
# Out:
# Text(0.5, 1.0, 'Data Points')

# %%
data=df.to_numpy().transpose()

# %%
data
# Out:
# array([[ 0.143  , -0.30467,  0.46625, ...,  6.1062 , -7.4094 , -0.12948],
#        [ 0.98493,  0.98562, -0.84003, ..., -5.9864 , -5.5205 , -8.8036 ]])

# %%
# Data Centering
k=np.mean(data, axis=1)
mu_x = k[0]
mu_y = k[1]

# %%
mu_x
# Out:
# 4.074999999685858e-07

# %%
mu_y
# Out:
# 2.2270000000723655e-07

# %%
a=data[0,:]-mu_x
b=data[1,:]-mu_y
ab=np.vstack((a,b))
ab
# Out:
# array([[ 0.14299959, -0.30467041,  0.46624959, ...,  6.10619959,
#         -7.40940041, -0.12948041],
#        [ 0.98492978,  0.98561978, -0.84003022, ..., -5.98640022,
#         -5.52050022, -8.80360022]])

# %%
sns.scatterplot(ab[0,:],ab[1,:])
plt.scatter(k[0],k[1],color='red')

# %%
X=np.asmatrix(ab)
X
# Out:
# matrix([[ 0.14299959, -0.30467041,  0.46624959, ...,  6.10619959,
#          -7.40940041, -0.12948041],
#         [ 0.98492978,  0.98561978, -0.84003022, ..., -5.98640022,
#          -5.52050022, -8.80360022]])

# %%
Xt=X.transpose()
Xt
# Out:
# matrix([[ 0.14299959,  0.98492978],
#         [-0.30467041,  0.98561978],
#         [ 0.46624959, -0.84003022],
#         ...,
#         [ 6.10619959, -5.98640022],
#         [-7.40940041, -5.52050022],
#         [-0.12948041, -8.80360022]])

# %%
C=np.matmul(X,Xt)/n
C
# Out:
# matrix([[14.76615576,  0.80885904],
#         [ 0.80885904, 16.85536339]])

# %%
# eigen vectors are the principle components and eigen values are the variance corresponding to that pc
eigenvalues, eigenvectors = np.linalg.eig(C)

s = eigenvalues.argsort()[::-1]   
eigenvalues = eigenvalues[s]
eigenvectors = eigenvectors[:,s]

# %%
eigenvalues
# Out:
# array([17.1319144 , 14.48960475])

# %%
eigenvectors
# Out:
# matrix([[-0.323516 , -0.9462227],
#         [-0.9462227,  0.323516 ]])

# %%
w1=np.array(eigenvectors[:,0]).flatten()
w2=np.array(eigenvectors[:,1]).flatten()

# %%
w1
# Out:
# array([-0.323516 , -0.9462227])

# %%
w2
# Out:
# array([-0.9462227,  0.323516 ])

# %%
print("Variance corresponding to principal component: ", w1, "is", eigenvalues[0])
print("Variance corresponding to principal component: ", w2, "is", eigenvalues[1])
# Out:
# Variance corresponding to principal component:  [-0.323516  -0.9462227] is 17.131914402444362
# Variance corresponding to principal component:  [-0.9462227  0.323516 ] is 14.489604749330638

# %%
Percentage_variance_pc1_centered = (eigenvalues[0]/(eigenvalues[0]+eigenvalues[1]))*100
Percentage_variance_pc2_centered = (eigenvalues[1]/(eigenvalues[0]+eigenvalues[1]))*100
print('pc1: ', Percentage_variance_pc1_centered, ', pc2: ',Percentage_variance_pc2_centered)
# Out:
# pc1:  54.17802452885222 , pc2:  45.82197547114778

# %%
new_X = np.array(np.matmul(Xt,eigenvectors))
new_X
# Out:
# array([[-0.97822557,  0.18333109],
#        [-0.83405005,  0.60714983],
#        [ 0.64401646, -0.71293917],
#        ...,
#        [ 3.68901448, -7.71452094],
#        [ 7.62068223,  5.22497267],
#        [ 8.37205534, -2.72558827]])

# %%
sns.scatterplot(ab[0,:],ab[1,:])
plt.scatter(k[0],k[1],color='red')
plt.plot([0,10*w1[0]],[0,10*w1[1]],color='magenta', label='w1')
plt.plot([0,10*w2[0]],[0,10*w2[1]],color='green',label='w2')
sns.scatterplot(new_X[:,0]*w1[0],new_X[:,0]*w1[1], color = 'yellow')
sns.scatterplot(new_X[:,1]*w2[0],new_X[:,1]*w2[1], color = 'grey')
plt.xlabel('feature1')
plt.ylabel('feature2')
plt.legend()

# %% [markdown]
# ### (1) ii. Study the effect of running PCA without centering the data-set. What are your observations? Does Centering help?

# %%
X_nc=np.asmatrix(data)
X_nc
# Out:
# matrix([[ 0.143  , -0.30467,  0.46625, ...,  6.1062 , -7.4094 , -0.12948],
#         [ 0.98493,  0.98562, -0.84003, ..., -5.9864 , -5.5205 , -8.8036 ]])

# %%
Xt_nc=X_nc.transpose()
Xt_nc
# Out:
# matrix([[ 0.143  ,  0.98493],
#         [-0.30467,  0.98562],
#         [ 0.46625, -0.84003],
#         ...,
#         [ 6.1062 , -5.9864 ],
#         [-7.4094 , -5.5205 ],
#         [-0.12948, -8.8036 ]])

# %%
C_nc=np.matmul(X_nc,Xt_nc)/n
C_nc
# Out:
# matrix([[14.76615576,  0.80885904],
#         [ 0.80885904, 16.85536339]])

# %%
# eigen vectors are the principle components and eigen values are the variance corresponding to that pc
eigenvalues_nc, eigenvectors_nc = np.linalg.eig(C_nc)

s_nc = eigenvalues_nc.argsort()[::-1]   
eigenvalues_nc = eigenvalues_nc[s_nc]
eigenvectors_nc = eigenvectors_nc[:,s_nc]

# %%
eigenvalues_nc
# Out:
# array([17.1319144 , 14.48960475])

# %%
eigenvectors_nc
# Out:
# matrix([[-0.323516 , -0.9462227],
#         [-0.9462227,  0.323516 ]])

# %%
w1_nc=np.array(eigenvectors[:,0]).flatten()
w2_nc=np.array(eigenvectors[:,1]).flatten()

# %%
print("Variance corresponding to principal component: ", w1_nc, "is", eigenvalues[0])
print("Variance corresponding to principal component: ", w2_nc, "is", eigenvalues[1])
# Out:
# Variance corresponding to principal component:  [-0.323516  -0.9462227] is 17.131914402444362
# Variance corresponding to principal component:  [-0.9462227  0.323516 ] is 14.489604749330638

# %%
print(eigenvalues_nc[0]>eigenvalues[0])
print(eigenvalues_nc[1]>eigenvalues[1])
# Out:
# True
# True

# %%
Percentage_variance_pc1_uncentered = (eigenvalues_nc[0]/(eigenvalues_nc[0]+eigenvalues_nc[1]))*100
Percentage_variance_pc2_uncentered = (eigenvalues_nc[1]/(eigenvalues_nc[0]+eigenvalues_nc[1]))*100
print('pc1: ', Percentage_variance_pc1_uncentered, ', pc2: ',Percentage_variance_pc2_uncentered)
# Out:
# pc1:  54.178024528852205 , pc2:  45.82197547114779

# %%
new_X_nc = np.array(np.matmul(Xt_nc,eigenvectors_nc))
new_X_nc
# Out:
# array([[-0.97822591,  0.18333077],
#        [-0.83405039,  0.60714951],
#        [ 0.64401612, -0.71293948],
#        ...,
#        [ 3.68901414, -7.71452125],
#        [ 7.62068189,  5.22497236],
#        [ 8.372055  , -2.72558858]])

# %%
df.plot(x ='x', y='y', kind = 'scatter')
plt.plot([0,10*w1_nc[0]],[0,10*w1_nc[1]],color='magenta', label='w1')
plt.plot([0,10*w2_nc[0]],[0,10*w2_nc[1]],color='green',label='w2')
sns.scatterplot(new_X_nc[:,0]*w1_nc[0],new_X_nc[:,0]*w1_nc[1], color = 'yellow')
sns.scatterplot(new_X_nc[:,1]*w2_nc[0],new_X_nc[:,1]*w2_nc[1], color = 'grey')
plt.xlabel('feature1')
plt.ylabel('feature2')
plt.legend()

# %% [markdown]
# ### (1) iii. Write a piece of code to implement the Kernel PCA algorithm on this dataset. Plot the projection of each point in the dataset onto the top-2 components for each kernel. Use one plot for each kernel and in the case of (B), use a different plot for each value of σ

# %% [markdown]
# #### A. k(x, y) = (1 + xT y)^d for d = {2, 3}

# %% [markdown]
# ###### For d=2:

# %%
p=2
K=np.empty([1000,1000])
for i in range(n):
    for j in range(n):
        K[i][j]=np.power((sum(np.multiply(data[:,i],data[:,j]))+1),p)

# %%
K
# Out:
# array([[3.96223398e+00, 3.71409559e+00, 5.72659268e-02, ...,
#         1.61845157e+01, 3.02153628e+01, 5.91275704e+01],
#        [3.71409559e+00, 4.26121308e+00, 8.99834642e-04, ...,
#         4.57069499e+01, 4.76851648e+00, 5.83322549e+01],
#        [5.72659268e-02, 8.99834642e-04, 3.69808078e+00, ...,
#         7.87793169e+01, 4.76441007e+00, 6.94708590e+01],
#        ...,
#        [1.61845157e+01, 4.57069499e+01, 7.87793169e+01, ...,
#         5.49416923e+03, 1.25336020e+02, 2.79959935e+03],
#        [3.02153628e+01, 4.76851648e+00, 4.76441007e+00, ...,
#         1.25336020e+02, 7.46066284e+03, 2.55627749e+03],
#        [5.91275704e+01, 5.83322549e+01, 6.94708590e+01, ...,
#         2.79959935e+03, 2.55627749e+03, 6.16541208e+03]])

# %%
In=np.empty([1000,1000])
In.fill(1/1000)
In
# Out:
# array([[0.001, 0.001, 0.001, ..., 0.001, 0.001, 0.001],
#        [0.001, 0.001, 0.001, ..., 0.001, 0.001, 0.001],
#        [0.001, 0.001, 0.001, ..., 0.001, 0.001, 0.001],
#        ...,
#        [0.001, 0.001, 0.001, ..., 0.001, 0.001, 0.001],
#        [0.001, 0.001, 0.001, ..., 0.001, 0.001, 0.001],
#        [0.001, 0.001, 0.001, ..., 0.001, 0.001, 0.001]])

# %%
Kc=K-np.matmul(In,K)-np.matmul(K,In)+np.matmul(np.matmul(In,K),In)

# %%
Kc
# Out:
# array([[  472.6514272 ,   472.02530375,   471.15703819, ...,
#          -593.72254285,  -874.7179173 ,  -763.74135231],
#        [  472.02530375,   472.1944362 ,   470.72268705, ...,
#          -564.57809378,  -900.54274871,  -764.91465279],
#        [  471.15703819,   470.72268705,   477.20843209, ...,
#          -528.71716262,  -897.75829102,  -750.9874846 ],
#        ...,
#        [ -593.72254285,  -564.57809378,  -528.71716262, ...,
#          3805.66591912, -1858.19351179,   898.13417179],
#        [ -874.7179173 ,  -900.54274871,  -897.75829102, ...,
#         -1858.19351179,  5182.1070889 ,   359.78609535],
#        [ -763.74135231,  -764.91465279,  -750.9874846 , ...,
#           898.13417179,   359.78609535,  4050.98503774]])

# %%
eigenvalues_kc, eigenvectors_kc = np.linalg.eig(Kc)

s_kc = eigenvalues_kc.argsort()[::-1]   
eigenvalues_kc = eigenvalues_kc[s_kc]
eigenvectors_kc = eigenvectors_kc[:,s_kc]

# %%
eigenvalues_kc=eigenvalues_kc.real
eigenvalues_kc
# Out:
# array([ 5.60408032e+05,  4.97707378e+05,  4.23270529e+05,  3.39999467e+04,
#         2.86264368e+04,  1.76955203e-10,  2.41110932e-11,  2.41110932e-11,
#         2.05771619e-11,  2.05771619e-11,  2.04155098e-11,  2.04155098e-11,
#         2.02047756e-11,  1.97957308e-11,  1.97957308e-11,  1.88594532e-11,
#         1.88594532e-11,  1.86072481e-11,  1.84857113e-11,  1.84857113e-11,
#         1.78068190e-11,  1.74560540e-11,  1.63410864e-11,  1.63410864e-11,
#         1.62847315e-11,  1.62847315e-11,  1.58345043e-11,  1.58345043e-11,
#         1.57074417e-11,  1.57074417e-11,  1.49743981e-11,  1.44273768e-11,
#         1.44273768e-11,  1.43445704e-11,  1.43445704e-11,  1.41479784e-11,
#         1.40911512e-11,  1.40911512e-11,  1.36264636e-11,  1.36264636e-11,
#         1.34896810e-11,  1.34896810e-11,  1.32573132e-11,  1.32573132e-11,
#         1.32297460e-11,  1.32297460e-11,  1.23526588e-11,  1.23526588e-11,
#         1.22981746e-11,  1.22981746e-11,  1.21976618e-11,  1.21976618e-11,
#         1.17696039e-11,  1.17696039e-11,  1.13823954e-11,  1.13823954e-11,
#         1.13626078e-11,  1.13626078e-11,  1.09069303e-11,  1.09069303e-11,
#         1.08657662e-11,  1.08657662e-11,  1.04026276e-11,  1.02820859e-11,
#         1.02820859e-11,  1.01386391e-11,  1.01165485e-11,  1.01165485e-11,
#         1.01054134e-11,  1.01054134e-11,  9.71232591e-12,  9.71232591e-12,
#         9.49757082e-12,  9.36931717e-12,  9.36931717e-12,  9.14939344e-12,
#         8.90036814e-12,  8.90036814e-12,  8.76215882e-12,  8.76215882e-12,
#         8.58523842e-12,  8.58523842e-12,  8.54882083e-12,  8.54882083e-12,
#         8.45350049e-12,  8.45350049e-12,  8.19240728e-12,  8.05879098e-12,
#         8.05879098e-12,  7.91311356e-12,  7.91311356e-12,  7.54941724e-12,
#         7.54941724e-12,  7.26482461e-12,  7.26482461e-12,  7.13740835e-12,
#         7.13740835e-12,  7.10175706e-12,  7.10175706e-12,  6.96939545e-12,
#         6.96939545e-12,  6.66059196e-12,  6.60263938e-12,  6.60263938e-12,
#         6.59603730e-12,  6.59603730e-12,  6.29531650e-12,  6.20212272e-12,
#         6.20212272e-12,  6.01961114e-12,  6.01961114e-12,  5.94380163e-12,
#         5.94380163e-12,  5.87288002e-12,  5.87288002e-12,  5.56456765e-12,
#         5.48137132e-12,  5.48137132e-12,  5.47954619e-12,  5.47954619e-12,
#         5.19527439e-12,  5.19527439e-12,  5.15818238e-12,  5.15635725e-12,
#         5.15635725e-12,  5.04076859e-12,  4.88114553e-12,  4.86859894e-12,
#         4.86859894e-12,  4.76924416e-12,  4.76924416e-12,  4.67108243e-12,
#         4.67108243e-12,  4.63592718e-12,  4.63592718e-12,  4.47437851e-12,
#         4.47437851e-12,  4.40562224e-12,  4.40562224e-12,  4.34139327e-12,
#         4.32748191e-12,  4.32748191e-12,  4.23902381e-12,  4.23902381e-12,
#         4.03358053e-12,  4.03358053e-12,  3.98234889e-12,  3.98234889e-12,
#         3.95952958e-12,  3.95952958e-12,  3.66610399e-12,  3.61119588e-12,
#         3.61119588e-12,  3.55471517e-12,  3.55471517e-12,  3.48689250e-12,
#         3.48689250e-12,  3.44538133e-12,  3.44538133e-12,  3.30417373e-12,
#         3.30417373e-12,  3.16991579e-12,  3.16991579e-12,  3.15654958e-12,
#         3.15654958e-12,  3.09796506e-12,  3.09796506e-12,  3.07804794e-12,
#         3.07804794e-12,  2.90344822e-12,  2.90344822e-12,  2.87118118e-12,
#         2.81760912e-12,  2.81760912e-12,  2.73072191e-12,  2.73072191e-12,
#         2.67402838e-12,  2.67402838e-12,  2.67220144e-12,  2.67220144e-12,
#         2.60092320e-12,  2.60092320e-12,  2.59870016e-12,  2.59870016e-12,
#         2.56578771e-12,  2.51236789e-12,  2.51236789e-12,  2.46842170e-12,
#         2.46842170e-12,  2.40480973e-12,  2.40480973e-12,  2.34215194e-12,
#         2.34215194e-12,  2.33826520e-12,  2.33826520e-12,  2.31610517e-12,
#         2.24107077e-12,  2.24107077e-12,  2.23583964e-12,  2.23583964e-12,
#         2.21872239e-12,  2.18459321e-12,  2.18459321e-12,  2.12635645e-12,
#         2.12635645e-12,  2.09360967e-12,  2.09360967e-12,  2.03338053e-12,
#         2.01997299e-12,  2.01997299e-12,  1.99074322e-12,  1.99074322e-12,
#         1.98373626e-12,  1.98373626e-12,  1.95475006e-12,  1.95475006e-12,
#         1.87335893e-12,  1.87335893e-12,  1.81957191e-12,  1.81957191e-12,
#         1.81401542e-12,  1.78509312e-12,  1.78509312e-12,  1.78254102e-12,
#         1.78254102e-12,  1.73662135e-12,  1.73662135e-12,  1.72758986e-12,
#         1.72758986e-12,  1.72507566e-12,  1.72507566e-12,  1.70726305e-12,
#         1.70726305e-12,  1.67709676e-12,  1.67353438e-12,  1.67353438e-12,
#         1.65193180e-12,  1.65193180e-12,  1.61235378e-12,  1.61235378e-12,
#         1.59241938e-12,  1.59241938e-12,  1.55214470e-12,  1.55214470e-12,
#         1.53689524e-12,  1.53689524e-12,  1.49362819e-12,  1.46315582e-12,
#         1.46315582e-12,  1.44398560e-12,  1.44398560e-12,  1.43493052e-12,
#         1.43493052e-12,  1.39104241e-12,  1.38051321e-12,  1.38051321e-12,
#         1.36377027e-12,  1.36377027e-12,  1.33548033e-12,  1.33548033e-12,
#         1.32881831e-12,  1.32881831e-12,  1.31834305e-12,  1.31834305e-12,
#         1.24862043e-12,  1.24862043e-12,  1.24472301e-12,  1.24472301e-12,
#         1.22403445e-12,  1.22403445e-12,  1.19553111e-12,  1.19553111e-12,
#         1.18924551e-12,  1.18924551e-12,  1.16075182e-12,  1.16075182e-12,
#         1.15127143e-12,  1.15127143e-12,  1.14310601e-12,  1.13399017e-12,
#         1.13399017e-12,  1.11295873e-12,  1.11295873e-12,  1.11040090e-12,
#         1.11040090e-12,  1.09604368e-12,  1.09604368e-12,  1.07569161e-12,
#         1.07569161e-12,  1.07291544e-12,  1.07291544e-12,  1.06422938e-12,
#         1.06422938e-12,  1.03412144e-12,  1.03412144e-12,  1.02860594e-12,
#         1.02610179e-12,  1.02610179e-12,  1.02234310e-12,  1.02061624e-12,
#         1.02061624e-12,  1.02049672e-12,  1.02049672e-12,  1.01381019e-12,
#         1.01381019e-12,  9.60496418e-13,  9.60496418e-13,  9.35948290e-13,
#         9.35948290e-13,  9.18204983e-13,  9.18204983e-13,  9.15563737e-13,
#         9.15563737e-13,  9.09205034e-13,  9.09205034e-13,  9.04890042e-13,
#         9.04890042e-13,  8.59610564e-13,  8.59610564e-13,  8.56131467e-13,
#         8.56131467e-13,  8.43536066e-13,  8.43536066e-13,  8.42112347e-13,
#         8.42112347e-13,  8.21638012e-13,  8.21638012e-13,  8.20113646e-13,
#         8.20113646e-13,  8.18964757e-13,  8.18964757e-13,  8.16341389e-13,
#         8.16341389e-13,  8.15213040e-13,  8.15213040e-13,  7.92764630e-13,
#         7.92764630e-13,  7.87961473e-13,  7.87961473e-13,  7.84244349e-13,
#         7.84244349e-13,  7.61699009e-13,  7.61699009e-13,  7.53220950e-13,
#         7.53220950e-13,  7.51545694e-13,  7.51545694e-13,  7.44280861e-13,
#         7.44280861e-13,  7.40332130e-13,  7.40332130e-13,  7.37430956e-13,
#         7.37430956e-13,  7.34365130e-13,  7.34365130e-13,  7.30521075e-13,
#         7.30521075e-13,  7.00351715e-13,  7.00351715e-13,  6.81982806e-13,
#         6.81982806e-13,  6.70270837e-13,  6.70270837e-13,  6.67338750e-13,
#         6.67338750e-13,  6.54213509e-13,  6.54213509e-13,  6.45493912e-13,
#         6.34868344e-13,  6.34868344e-13,  6.29071645e-13,  6.29071645e-13,
#         6.01794353e-13,  6.01794353e-13,  5.98094406e-13,  5.98094406e-13,
#         5.87772449e-13,  5.87772449e-13,  5.84784408e-13,  5.84784408e-13,
#         5.84328269e-13,  5.84328269e-13,  5.81005121e-13,  5.81005121e-13,
#         5.73032601e-13,  5.73032601e-13,  5.55490221e-13,  5.55490221e-13,
#         5.53268756e-13,  5.53268756e-13,  5.49723962e-13,  5.49723962e-13,
#         5.15461968e-13,  5.15461968e-13,  5.14759106e-13,  5.14759106e-13,
#         5.03187616e-13,  5.03187616e-13,  4.95943505e-13,  4.95943505e-13,
#         4.55095335e-13,  4.55095335e-13,  4.46852270e-13,  4.46852270e-13,
#         4.40202618e-13,  4.40202618e-13,  4.36338135e-13,  4.36338135e-13,
#         4.28677731e-13,  4.28677731e-13,  4.15173209e-13,  4.15173209e-13,
#         4.02893738e-13,  4.02893738e-13,  3.93563872e-13,  3.93563872e-13,
#         3.90342703e-13,  3.90342703e-13,  3.81255706e-13,  3.81255706e-13,
#         3.75516500e-13,  3.75516500e-13,  3.62673400e-13,  3.58817536e-13,
#         3.58817536e-13,  3.52427078e-13,  3.52427078e-13,  3.51770395e-13,
#         3.51770395e-13,  3.50949497e-13,  3.50949497e-13,  3.28477072e-13,
#         3.28477072e-13,  3.21825283e-13,  3.21825283e-13,  3.18245332e-13,
#         3.18245332e-13,  2.86575251e-13,  2.86575251e-13,  2.83472304e-13,
#         2.83472304e-13,  2.79577365e-13,  2.76127973e-13,  2.76127973e-13,
#         2.74439999e-13,  2.74439999e-13,  2.73083121e-13,  2.73083121e-13,
#         2.64390997e-13,  2.64390997e-13,  2.30273363e-13,  2.30273363e-13,
#         2.20370905e-13,  2.20370905e-13,  1.97918200e-13,  1.97918200e-13,
#         1.97312068e-13,  1.97312068e-13,  1.90115727e-13,  1.90115727e-13,
#         1.88678210e-13,  1.88678210e-13,  1.87051794e-13,  1.87051794e-13,
#         1.80829104e-13,  1.80829104e-13,  1.78752449e-13,  1.78752449e-13,
#         1.71449262e-13,  1.71449262e-13,  1.65604784e-13,  1.65604784e-13,
#         1.51295699e-13,  1.51295699e-13,  1.46984545e-13,  1.46984545e-13,
#         1.42741188e-13,  1.42741188e-13,  1.00092098e-13,  1.00092098e-13,
#         9.95733163e-14,  9.95733163e-14,  9.66990352e-14,  9.66990352e-14,
#         8.51869122e-14,  8.51869122e-14,  7.97258186e-14,  7.97258186e-14,
#         7.84658265e-14,  7.84658265e-14,  6.56122913e-14,  6.56122913e-14,
#         6.04669188e-14,  6.04669188e-14,  2.93300424e-14,  2.93300424e-14,
#         2.22744531e-14,  2.22744531e-14,  8.98996772e-15,  8.98996772e-15,
#         6.77509189e-15,  6.77509189e-15, -3.64205208e-15, -3.64205208e-15,
#        -9.40531994e-15, -9.40531994e-15, -1.20396085e-14, -1.20396085e-14,
#        -2.55571356e-14, -2.55571356e-14, -3.70070603e-14, -3.70070603e-14,
#        -6.47493330e-14, -6.47493330e-14, -7.12216942e-14, -7.12216942e-14,
#        -7.87650822e-14, -7.87650822e-14, -7.89138232e-14, -7.89138232e-14,
#        -9.48882369e-14, -9.48882369e-14, -1.07550816e-13, -1.07550816e-13,
#        -1.15700292e-13, -1.15700292e-13, -1.15709510e-13, -1.15709510e-13,
#        -1.16741905e-13, -1.16741905e-13, -1.19995388e-13, -1.19995388e-13,
#        -1.25163842e-13, -1.25163842e-13, -1.28374208e-13, -1.28374208e-13,
#        -1.34319779e-13, -1.34319779e-13, -1.36857083e-13, -1.36857083e-13,
#        -1.61921674e-13, -1.61921674e-13, -1.63244069e-13, -1.76002399e-13,
#        -1.76002399e-13, -1.80421012e-13, -1.80421012e-13, -1.97296711e-13,
#        -1.97296711e-13, -1.98656357e-13, -1.98656357e-13, -2.07917250e-13,
#        -2.07917250e-13, -2.23331507e-13, -2.23331507e-13, -2.35037476e-13,
#        -2.35037476e-13, -2.40901621e-13, -2.40901621e-13, -2.53106293e-13,
#        -2.53106293e-13, -2.68707136e-13, -2.68707136e-13, -2.78063465e-13,
#        -2.78063465e-13, -2.82335927e-13, -2.82335927e-13, -2.87534561e-13,
#        -2.87534561e-13, -2.99131119e-13, -2.99131119e-13, -3.03840842e-13,
#        -3.03840842e-13, -3.08447376e-13, -3.08447376e-13, -3.16455079e-13,
#        -3.16455079e-13, -3.24695561e-13, -3.24695561e-13, -3.30813489e-13,
#        -3.30813489e-13, -3.54069638e-13, -3.54069638e-13, -3.57208763e-13,
#        -3.57208763e-13, -3.71859164e-13, -3.71859164e-13, -3.87686876e-13,
#        -3.87686876e-13, -4.29826954e-13, -4.29826954e-13, -4.30730288e-13,
#        -4.30730288e-13, -4.33595520e-13, -4.33595520e-13, -4.43663847e-13,
#        -4.43663847e-13, -4.47363895e-13, -4.47363895e-13, -4.51339920e-13,
#        -4.51339920e-13, -4.62651514e-13, -4.62651514e-13, -4.70561785e-13,
#        -4.70561785e-13, -4.73084869e-13, -4.73084869e-13, -4.73995350e-13,
#        -4.73995350e-13, -4.90208823e-13, -4.90208823e-13, -5.05682951e-13,
#        -5.05682951e-13, -5.18502358e-13, -5.18502358e-13, -5.20317406e-13,
#        -5.20317406e-13, -5.27110778e-13, -5.27110778e-13, -5.27835376e-13,
#        -5.27835376e-13, -5.30294552e-13, -5.30294552e-13, -5.54973488e-13,
#        -5.62429466e-13, -5.62429466e-13, -5.63128384e-13, -5.63128384e-13,
#        -5.63219001e-13, -5.63219001e-13, -5.86087378e-13, -5.86087378e-13,
#        -5.90286115e-13, -5.90286115e-13, -5.93733809e-13, -5.93733809e-13,
#        -5.93832041e-13, -6.03817388e-13, -6.03817388e-13, -6.26360723e-13,
#        -6.26360723e-13, -6.31819500e-13, -6.31819500e-13, -6.32835519e-13,
#        -6.32835519e-13, -6.60550541e-13, -6.60550541e-13, -6.80198728e-13,
#        -6.80198728e-13, -6.89402708e-13, -6.89402708e-13, -7.05010796e-13,
#        -7.05010796e-13, -7.08407860e-13, -7.08407860e-13, -7.21076363e-13,
#        -7.21076363e-13, -7.30844430e-13, -7.30844430e-13, -7.41111643e-13,
#        -7.41111643e-13, -7.50888164e-13, -7.50888164e-13, -7.56481999e-13,
#        -7.56481999e-13, -7.65775004e-13, -7.65775004e-13, -7.84079534e-13,
#        -7.84079534e-13, -8.07048815e-13, -8.07048815e-13, -8.15876297e-13,
#        -8.15876297e-13, -8.39120645e-13, -8.39120645e-13, -8.40830327e-13,
#        -8.40830327e-13, -8.45649794e-13, -8.51067078e-13, -8.51067078e-13,
#        -8.56430990e-13, -8.56430990e-13, -8.69320426e-13, -8.69320426e-13,
#        -8.74188424e-13, -8.74188424e-13, -8.74568857e-13, -8.74568857e-13,
#        -8.91322592e-13, -8.91322592e-13, -8.95678638e-13, -9.44513420e-13,
#        -9.49033894e-13, -9.49033894e-13, -9.51358237e-13, -9.51358237e-13,
#        -9.64245396e-13, -9.64245396e-13, -9.77952727e-13, -9.77952727e-13,
#        -9.87168153e-13, -9.87168153e-13, -1.00607596e-12, -1.00607596e-12,
#        -1.00820547e-12, -1.00820547e-12, -1.01239954e-12, -1.01239954e-12,
#        -1.01913010e-12, -1.01913010e-12, -1.01961979e-12, -1.01961979e-12,
#        -1.04387875e-12, -1.04387875e-12, -1.05034831e-12, -1.05380032e-12,
#        -1.05380032e-12, -1.06360579e-12, -1.06360579e-12, -1.07209445e-12,
#        -1.07209445e-12, -1.07217739e-12, -1.12377186e-12, -1.15465325e-12,
#        -1.15465325e-12, -1.18350946e-12, -1.18350946e-12, -1.18445046e-12,
#        -1.18445046e-12, -1.19395788e-12, -1.19395788e-12, -1.21712163e-12,
#        -1.21712163e-12, -1.22492669e-12, -1.22492669e-12, -1.25019806e-12,
#        -1.25019806e-12, -1.25181840e-12, -1.25642786e-12, -1.25642786e-12,
#        -1.27580676e-12, -1.27580676e-12, -1.29984556e-12, -1.29984556e-12,
#        -1.30134993e-12, -1.30134993e-12, -1.30210625e-12, -1.30210625e-12,
#        -1.36294055e-12, -1.36294055e-12, -1.38711098e-12, -1.38711098e-12,
#        -1.38889349e-12, -1.38889349e-12, -1.40447250e-12, -1.40447250e-12,
#        -1.41762216e-12, -1.41762216e-12, -1.42003160e-12, -1.42003160e-12,
#        -1.45998589e-12, -1.48862777e-12, -1.48862777e-12, -1.49805593e-12,
#        -1.49805593e-12, -1.52050655e-12, -1.52050655e-12, -1.54493228e-12,
#        -1.54493228e-12, -1.55472055e-12, -1.55472055e-12, -1.56312173e-12,
#        -1.56312173e-12, -1.66582432e-12, -1.66582432e-12, -1.68129941e-12,
#        -1.68129941e-12, -1.70122073e-12, -1.70122073e-12, -1.75481886e-12,
#        -1.75481886e-12, -1.86487321e-12, -1.86487321e-12, -1.86915101e-12,
#        -1.86915101e-12, -1.87571228e-12, -1.87571228e-12, -1.87894538e-12,
#        -1.87894538e-12, -1.88673813e-12, -1.88673813e-12, -1.90415182e-12,
#        -1.90415182e-12, -1.90563938e-12, -1.93483451e-12, -1.93483451e-12,
#        -1.99467696e-12, -1.99467696e-12, -1.99497254e-12, -2.15219603e-12,
#        -2.15219603e-12, -2.16809421e-12, -2.16809421e-12, -2.21635163e-12,
#        -2.21635163e-12, -2.23287941e-12, -2.31813382e-12, -2.34604188e-12,
#        -2.34604188e-12, -2.34988174e-12, -2.34988174e-12, -2.36475820e-12,
#        -2.36475820e-12, -2.48647719e-12, -2.48647719e-12, -2.57784307e-12,
#        -2.58749746e-12, -2.58749746e-12, -2.59296939e-12, -2.59296939e-12,
#        -2.66912182e-12, -2.66912182e-12, -2.69613407e-12, -2.78125370e-12,
#        -2.78125370e-12, -2.79821657e-12, -2.79821657e-12, -2.80259384e-12,
#        -2.80259384e-12, -2.81886034e-12, -2.81886034e-12, -2.83302617e-12,
#        -2.83302617e-12, -2.83951381e-12, -2.83951381e-12, -2.85910761e-12,
#        -2.85910761e-12, -2.86844258e-12, -2.86844258e-12, -2.93470735e-12,
#        -2.93470735e-12, -2.95974761e-12, -2.95974761e-12, -3.08795878e-12,
#        -3.08795878e-12, -3.15124469e-12, -3.15124469e-12, -3.23940806e-12,
#        -3.41269467e-12, -3.41269467e-12, -3.41493181e-12, -3.41493181e-12,
#        -3.52109233e-12, -3.52109233e-12, -3.67582404e-12, -3.67582404e-12,
#        -3.73864057e-12, -3.76812357e-12, -3.76812357e-12, -3.90066911e-12,
#        -3.90066911e-12, -3.98038029e-12, -3.98038029e-12, -4.04892697e-12,
#        -4.04892697e-12, -4.07410329e-12, -4.07410329e-12, -4.15685648e-12,
#        -4.15685648e-12, -4.17859428e-12, -4.17859428e-12, -4.41481868e-12,
#        -4.41481868e-12, -4.72068699e-12, -4.72068699e-12, -4.80345943e-12,
#        -4.80345943e-12, -4.81432618e-12, -4.81940270e-12, -4.81940270e-12,
#        -4.89301624e-12, -4.89301624e-12, -4.91154712e-12, -4.91154712e-12,
#        -5.18628100e-12, -5.18628100e-12, -5.26151509e-12, -5.26151509e-12,
#        -5.37193787e-12, -5.37193787e-12, -5.68596175e-12, -5.68596175e-12,
#        -5.72493734e-12, -5.72493734e-12, -6.01427511e-12, -6.01427511e-12,
#        -6.05289931e-12, -6.05289931e-12, -6.18134026e-12, -6.18134026e-12,
#        -6.42490354e-12, -6.42490354e-12, -6.76588146e-12, -6.76588146e-12,
#        -6.77331215e-12, -6.77331215e-12, -6.94657054e-12, -7.12329238e-12,
#        -7.12329238e-12, -7.38041888e-12, -7.38041888e-12, -7.40602161e-12,
#        -7.40602161e-12, -7.51131013e-12, -7.51131013e-12, -7.76350688e-12,
#        -7.76350688e-12, -7.77944069e-12, -7.77944069e-12, -7.87061532e-12,
#        -7.87061532e-12, -8.06420116e-12, -8.06420116e-12, -8.06680355e-12,
#        -8.40764460e-12, -8.40764460e-12, -8.84522233e-12, -8.84522233e-12,
#        -8.86954812e-12, -8.86954812e-12, -9.13132761e-12, -9.13132761e-12,
#        -9.27148849e-12, -9.27148849e-12, -9.50067893e-12, -1.00299597e-11,
#        -1.00299597e-11, -1.00888650e-11, -1.00888650e-11, -1.02468665e-11,
#        -1.02468665e-11, -1.04817355e-11, -1.04817355e-11, -1.04971962e-11,
#        -1.04971962e-11, -1.09620260e-11, -1.09620260e-11, -1.12753025e-11,
#        -1.12753025e-11, -1.14940102e-11, -1.14940102e-11, -1.18359260e-11,
#        -1.18359260e-11, -1.18669369e-11, -1.18669369e-11, -1.22191374e-11,
#        -1.22191374e-11, -1.25164732e-11, -1.25164732e-11, -1.25290010e-11,
#        -1.25290010e-11, -1.29936445e-11, -1.31438059e-11, -1.31438059e-11,
#        -1.37143978e-11, -1.37143978e-11, -1.38647808e-11, -1.38647808e-11,
#        -1.39898184e-11, -1.40257507e-11, -1.40257507e-11, -1.48740016e-11,
#        -1.48740016e-11, -1.49352848e-11, -1.49352848e-11, -1.53975226e-11,
#        -1.53975226e-11, -1.59686127e-11, -1.59686127e-11, -1.61618399e-11,
#        -1.62576842e-11, -1.67657831e-11, -1.67657831e-11, -1.73732325e-11,
#        -1.74773715e-11, -1.74773715e-11, -1.76086386e-11, -1.77356464e-11,
#        -1.77356464e-11, -1.81376876e-11, -1.89919188e-11, -1.96721928e-11,
#        -2.00903256e-11, -2.01908789e-11, -2.01908789e-11, -2.08177398e-11,
#        -2.42012059e-11, -2.42012059e-11, -2.48799027e-11, -1.67281042e-10])

# %%
eigenvectors_kc=eigenvectors_kc.real
eigenvectors_kc
# Out:
# array([[-0.0216369 ,  0.00218602, -0.02203242, ..., -0.00171451,
#          0.00831614, -0.01312328],
#        [-0.02193616,  0.00284154, -0.02147589, ...,  0.01556788,
#         -0.0004259 , -0.0271699 ],
#        [-0.02234344,  0.00269801, -0.0213343 , ...,  0.00634267,
#          0.01701483, -0.02153443],
#        ...,
#        [-0.00159556,  0.05550981,  0.07025395, ...,  0.00141132,
#         -0.06706025, -0.04557788],
#        [ 0.05062236, -0.08371748,  0.01749212, ...,  0.01845552,
#          0.02725213, -0.01645571],
#        [ 0.07297801,  0.04128522, -0.01032308, ...,  0.04613266,
#          0.05162857, -0.02738304]])

# %%
alpha = np.empty([1000,1000])
for i in range(1000):
    alpha[:,i] = eigenvectors_kc[:,i]/np.power(1000*abs(eigenvalues_kc[i]),(1/2))

# %%
alpha
# Out:
# array([[-9.13992896e-07,  9.79867371e-08, -1.07091035e-06, ...,
#         -1.10210139e+01,  5.27226535e+01, -3.20862584e+01],
#        [-9.26634376e-07,  1.27369939e-07, -1.04385953e-06, ...,
#          1.00071626e+02, -2.70010474e+00, -6.64300768e+01],
#        [-9.43839074e-07,  1.20936291e-07, -1.03697777e-06, ...,
#          4.07712187e+01,  1.07870660e+02, -5.26514199e+01],
#        ...,
#        [-6.74002675e-08,  2.48818529e-06,  3.41477218e-06, ...,
#          9.07206354e+00, -4.25148684e+02, -1.11437345e+02],
#        [ 2.13840643e-06, -3.75257271e-06,  8.50223947e-07, ...,
#          1.18633625e+02,  1.72773076e+02, -4.02340018e+01],
#        [ 3.08276079e-06,  1.85057874e-06, -5.01765127e-07, ...,
#          2.96544611e+02,  3.27314870e+02, -6.69511944e+01]])

# %%
mapped=np.matmul(Kc,alpha)
mapped
# Out:
# array([[-5.12208960e-01,  4.87687220e-02, -4.53284790e-01, ...,
#         -3.14321369e-09, -9.31322575e-10,  6.98491931e-09],
#        [-5.19293347e-01,  6.33929582e-02, -4.41834975e-01, ...,
#         -3.72529030e-09, -2.32830644e-10,  9.08039510e-09],
#        [-5.28934998e-01,  6.01908845e-02, -4.38922131e-01, ...,
#         -2.79396772e-09,  3.95812094e-09,  8.84756446e-09],
#        ...,
#        [-3.77716513e-02,  1.23838818e+00,  1.44537243e+00, ...,
#          4.65661287e-09,  1.72294676e-08,  1.49011612e-08],
#        [ 1.19838014e+00, -1.86768312e+00,  3.59874740e-01, ...,
#         -2.79396772e-09, -6.98491931e-10, -1.86264515e-09],
#        [ 1.72760391e+00,  9.21046692e-01, -2.12382391e-01, ...,
#         -1.07102096e-08, -1.11758709e-08,  4.30736691e-09]])

# %%
sns.scatterplot(mapped[:,0],mapped[:,1])
plt.xlabel('projection on alpha1')
plt.ylabel('projection on alpha2')
# Out:
# Text(0, 0.5, 'projection on alpha2')

# %% [markdown]
# ###### For d=3:

# %%
p=3
K2=np.empty([1000,1000])
for i in range(n):
    for j in range(n):
        K2[i][j]=np.power((sum(np.multiply(data[:,i],data[:,j]))+1),p)

# %%
In2=np.empty([1000,1000])
In2.fill(1/1000)
Kc2=K2-np.matmul(In2,K2)-np.matmul(K2,In2)+np.matmul(np.matmul(In2,K2),In2)

# %%
eigenvalues_kc2, eigenvectors_kc2 = np.linalg.eig(Kc2)

s_kc2 = eigenvalues_kc2.argsort()[::-1]   
eigenvalues_kc2 = eigenvalues_kc2[s_kc]
eigenvectors_kc2 = eigenvectors_kc2[:,s_kc]

# %%
eigenvalues_kc2=eigenvalues_kc2.real
eigenvectors_kc2=eigenvectors_kc2.real

# %%
alpha2 = np.empty([1000,1000])
for i in range(1000):
    alpha2[:,i] = eigenvectors_kc2[:,i]/np.power(1000*abs(eigenvalues_kc2[i]),(1/2))

# %%
mapped2=np.matmul(Kc2,alpha2)
mapped2
# Out:
# array([[ 6.24726983e-02, -3.84366069e-01, -1.13976211e-01, ...,
#         -7.45058060e-09,  3.60748663e-02, -7.84692622e-01],
#        [ 5.94797707e-02, -3.69905030e-01, -1.08677681e-01, ...,
#         -9.31322575e-09,  5.09320968e-02, -7.65732412e-01],
#        [ 1.71510044e-02, -4.09609829e-01, -1.28384571e-01, ...,
#         -9.31322575e-09, -5.27814264e-02, -7.56591790e-01],
#        ...,
#        [-6.74032125e+00, -1.50452306e+01,  4.21630665e+00, ...,
#         -2.98023224e-08,  6.01226453e-02,  3.13263525e+00],
#        [-1.71416963e+01,  1.38715483e+01,  1.05058492e+01, ...,
#         -9.31322575e-08,  1.08081659e-03,  5.06909224e-01],
#        [-1.84019163e+01, -6.90783842e+00, -7.60614046e+00, ...,
#         -1.41561031e-07,  3.15325307e-02, -2.89874354e-01]])

# %%
sns.scatterplot(mapped2[:,0],mapped2[:,1])
plt.xlabel('projection on alpha1')
plt.ylabel('projection on alpha2')
# Out:
# Text(0, 0.5, 'projection on alpha2')

# %%
sns.scatterplot(mapped[:,0],mapped[:,1],color='blue',label='d=2')
sns.scatterplot(mapped2[:,0],mapped2[:,1], color='green',label='d=3')
plt.xlabel('projection on alpha1')
plt.ylabel('projection on alpha2')
plt.legend()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
sns.scatterplot(mapped[:,0],mapped[:,1],color='blue',ax=axes[0])
sns.scatterplot(mapped2[:,0],mapped2[:,1], color='green',ax=axes[1])
axes[0].set_xlabel('projection on alpha1')
axes[0].set_ylabel('projection on alpha2')
axes[1].set_xlabel('projection on alpha1')
axes[1].set_ylabel('projection on alpha2')
axes[0].set_title('d=2')
axes[1].set_title('d=3')
fig.subplots_adjust(wspace=0.5)

# %% [markdown]
# #### B. k(x, y) = exp −(x−y)T (x−y)/(2σ^2) for σ = {0.1, 0.2, . . . , 1}

# %%
fig, axes = plt.subplots(5, 2, figsize=(15,30))
fig.subplots_adjust(hspace=0.5, wspace=0.5)

sigma = 0.1
for o1 in range(5):
    for o2 in range(2):
        K_exp=np.empty([1000,1000])
        for i in range(n):
            for j in range(n):
                K_exp[i][j]=math.exp(-(np.matmul((data[:,i]-data[:,j]),(data[:,i]-data[:,j])))/(2*sigma*sigma))

        In_exp=np.empty([1000,1000])
        In_exp.fill(1/1000)

        Kc_exp=K_exp-np.matmul(In_exp,K_exp)-np.matmul(K_exp,In_exp)+np.matmul(np.matmul(In_exp,K_exp),In_exp)

        eigenvalues_kc_exp, eigenvectors_kc_exp = np.linalg.eig(Kc_exp)

        s_kc_exp = eigenvalues_kc_exp.argsort()[::-1]   
        eigenvalues_kc_exp = eigenvalues_kc_exp[s_kc_exp]
        eigenvectors_kc_exp = eigenvectors_kc_exp[:,s_kc_exp]

        alpha_exp = np.empty([1000,1000])
        for i in range(1000):
            alpha_exp[:,i] = eigenvectors_kc_exp[:,i]/np.power(1000*abs(eigenvalues_kc_exp[i]),(1/2))

        mapped_exp=np.matmul(Kc_exp,alpha_exp)

        sns.scatterplot(mapped_exp[:,0],mapped_exp[:,1],color='blue',ax=axes[o1][o2])
        axes[o1][o2].set_xlabel('projection on alpha1')
        axes[o1][o2].set_ylabel('projection on alpha2')

        sigma=sigma+0.1
        
axes[0][0].set_title('Sigma = 0.1')
axes[0][1].set_title('Sigma = 0.2')
axes[1][0].set_title('Sigma = 0.3')
axes[1][1].set_title('Sigma = 0.4')
axes[2][0].set_title('Sigma = 0.5')
axes[2][1].set_title('Sigma = 0.6')
axes[3][0].set_title('Sigma = 0.7')
axes[3][1].set_title('Sigma = 0.8')
axes[4][0].set_title('Sigma = 0.9')
axes[4][1].set_title('Sigma = 1')
# Out:
# C:\Users\V-ABHIGNA\anaconda3\lib\site-packages\ipykernel_launcher.py:25: ComplexWarning: Casting complex values to real discards the imaginary part
# Text(0.5, 1.0, 'Sigma = 1')
